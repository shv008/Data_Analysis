# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker

# %%
#collecting data
df = pd.read_csv('netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
df.shape
# Out:
# (8807, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#DATA CLEANING 
#missing values analysis
df.isnull().sum().sort_values(ascending = True)
# Out:
# show_id            0
# type               0
# title              0
# release_year       0
# listed_in          0
# description        0
# duration           3
# rating             4
# date_added        10
# cast             825
# country          831
# director        2634
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#changing date time format
df['date_added'] = pd.to_datetime(df['date_added'] , format ='mixed')

# %%
df['country'].fillna("Unknown" , inplace = True)
# Out:
# C:\Users\shreya verma\AppData\Local\Temp\ipykernel_21636\524158033.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna("Unknown" , inplace = True)

# %%
#removing missing values
df = df.dropna()

# %%
df.nunique()
# Out:
# show_id         5696
# type               2
# title           5696
# director        4150
# cast            5510
# country          605
# date_added      1477
# release_year      72
# rating            14
# duration         205
# listed_in        346
# description     5673
# dtype: int64

# %%
#Data Cleaning: Dropping Unnecessary Columns
#n this step, we dropped the `show_id` and `description` columns from the original dataset.
#- `show_id` is a unique identifier and not required for our analysis.
#- `description` contains textual data which won’t be used in the current scope of EDA (but can be used later for NLP or sentiment analysis).
#We also reset the index to ensure the new DataFrame is clean and sequentially indexed.

new_df = df.drop(['show_id' , 'description'] , axis=1)
new_df.reset_index(drop=True , inplace= True)
new_df.head()
# Out:
#       type                             title                       director  \
# 0  TV Show                         Ganglands                Julien Leclercq
# 1  TV Show                     Midnight Mass                  Mike Flanagan
# 2    Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 3    Movie                           Sankofa                   Haile Gerima
# 4  TV Show     The Great British Baking Show                Andy Devonshire
#
#                                                 cast  \
# 0  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 1  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 2  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 3  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 4  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country date_added  release_year  \
# 0                                            Unknown 2021-09-24          2021
# ...

# %%
#📈 Distribution of Content Release Years
#In this step, we visualized the distribution of `release_year` using Seaborn's `displot()`.
#This helps us understand how the volume of Netflix content has changed over time. As shown in the plot, there has been a sharp increase in releases after 2010, peaking around 2018–2020, which aligns with Netflix's global expansion and rise in original productions.

sns.displot(new_df['release_year'])
plt.title('Distribution of Content Release Years on Netflix', fontsize=14)
plt.xlabel('Release Year')
plt.ylabel('Density')
plt.show()

# %%
#🔢 Rating Distribution Analysis

#In this step, we analyzed the distribution of content ratings using `value_counts()` and converted the result into a DataFrame for better readability.

#This shows how Netflix content is classified based on viewing suitability. Key insights:
#- `TV-MA` (Mature Audience) is the most common rating, indicating a large portion of Netflix content is intended for adults.
#- `TV-14` and `R` follow, also targeting older teens and adults.
#- There's relatively less content aimed at younger audiences (`TV-Y`, `G`, etc.).

#This distribution can help in understanding Netflix's target audience and content focus.

ratings = new_df['rating'].value_counts()
ratings_df = pd.DataFrame(ratings)
ratings_df
# Out:
#           count
# rating
# TV-MA      1939
# TV-14      1329
# R           789
# PG-13       477
# TV-PG       456
# PG          279
# TV-Y7       123
# TV-Y        102
# TV-G         96
# NR           58
# G            40
# TV-Y7-FV      3
# UR            3
# NC-17         2

# %%
#Count of Titles by Rating – Strip Plot
#In this step, a **strip plot** was used to visualize the distribution of content across different ratings. 
#Each dot represents the number of titles available under a specific rating category.
#This vertical strip plot gives a clean comparative view of the **frequency of ratings** and 
#clearly highlights that `TV-MA`, `TV-14`, and `R` dominate Netflix’s content library.
#While it's visually simple, this plot is best used when showing individual observations. 
#For summarized frequency counts like these, a **bar plot or horizontal bar chart** may offer better clarity

sns.relplot(x='count' , y='rating' , data=ratings_df)

# %%
countries = new_df['country'].value_counts()
countries
# Out:
# country
# United States                                    1846
# India                                             875
# Unknown                                           364
# United Kingdom                                    183
# Canada                                            107
#                                                  ...
# United Kingdom, Canada, France, United States       1
# United States, India, United Arab Emirates          1
# Spain, Canada, United States                        1
# United States, United Kingdom, Morocco              1
# Germany, Czech Republic                             1
# Name: count, Length: 605, dtype: int64

# %%
#GROUPING
country_grp = new_df.groupby(['country'])
india_df = country_grp.get_group('India')
india_df
# Out:
# C:\Users\shreya verma\AppData\Local\Temp\ipykernel_21636\566580073.py:3: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   india_df = country_grp.get_group('India')
#        type                  title                 director  \
# 12    Movie                  Jeans               S. Shankar
# 58    Movie       Angamaly Diaries     Lijo Jose Pellissery
# 62    Movie                 Anjaam             Rahul Rawail
# 64    Movie                 Dhanak          Nagesh Kukunoor
# 65    Movie                Gurgaon            Shanker Raman
# ...     ...                    ...                      ...
# 5671  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 5672  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 5689  Movie               Zed Plus  Chandra Prakash Dwivedi
# ...

# %%
### 🇮🇳 Content Trend Over Time in India by Type (Movie vs TV Show)

#This **count plot** visualizes the number of Indian titles released on Netflix each year, categorized by type:
#**Movie** and **TV Show**.
#Key observations:
#- There is a **significant rise in content** starting from 2010, with a peak around 2018–2019.
#- Movies (blue bars) have consistently outnumbered TV shows (orange bars), indicating Netflix’s stronger focus on 
#movie content in India.
#- TV shows have a much smaller footprint, though their presence has slightly grown in recent years.

#Customizations:
#- The x-axis is adjusted to show every 5th year for better readability using `ticker.MultipleLocator(5)`.
#- X-axis labels are rotated for clarity.

#> 📌 **Insight:** This upward trend reflects Netflix’s growing investment in Indian regional and Bollywood content,
#particularly around 2017–2019.

g = sns.countplot(x='release_year', hue='type' , data=india_df)
g.xaxis.set_major_locator(ticker.MultipleLocator(5))  # show every 5th year
g.tick_params(axis='x', rotation=45)                  # rotate labels
plt.tight_layout()
plt.show()
